# %% [markdown]
# # Seaborn
# Seaborn is a Python data visualization library built on top of Matplotlib.
#
# Why it’s useful: It provides a high-level interface for creating beautiful and informative statistical graphics with less code.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
data = pd.read_excel("C:/Users/Shubham/Downloads/Excel course/datasets/ESD.xlsx")
print(data)
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0    Research & Development  Female      Black   55 2016-04-08         141604
# ...

# %% [markdown]
# ## Line Plot
#
# * Compared `Age` across `Business` Unit with `Ethnicity` as hue.
# * Learned how to match color `palettes` dynamically with the number of categories.

# %%
num_categories = data["Ethnicity"].nunique()
color = sns.color_palette("viridis", num_categories)
sns.lineplot(data =data,x = "Business Unit", y = "Age", hue ="Ethnicity", palette= color )
plt.show()

# %%
data = sns.load_dataset("tips")
print(data)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ## FacetGrid with Barplot
#
# * Split data by `smoker` status and compared `tip` by `day` with `sex` as hue.
# * Learned about specifying `order` to control categorical axis.

# %%
a = sns.FacetGrid(data,col = "smoker",height =2,hue= "sex")
day_order = data["day"].unique()
a.map(sns.barplot,"day","tip", order=day_order)
plt.show()

# %% [markdown]
# ## Relational Plot (`relplot`)
#
# * Explored relationship between `tip` and `total_bill`, with hue (`sex`), size (`smoker`), and column (`day`).
# * Practiced combining multiple dimensions in a single visualization.

# %%
sns.relplot(data= data,x ="tip",y ="total_bill",hue= "sex", col = "day",size = "smoker")
plt.show()

# %% [markdown]
# ## Bar Plot with Custom Order and Palette
#
# * Used barplot to compare `tip` across `days` with `sex` as hue.
# * Customized using palette "`GnBu`" and manually set order (`Sun` → `Sat` → `Fri` → `Thur`).

# %%
sns.barplot(data =data,x = "day", y = "tip",hue = "sex",palette = "GnBu",order = ["Sun","Sat","Fri","Thur"])
plt.plot()
# Out:
# []

# %%
data = sns.load_dataset("titanic")
print(data)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ## Histogram + KDE
#
# * Used Titanic dataset to visualize `age` distribution, grouped by `who`.
# * Applied bins and kernel density estimation (`KDE`).

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(8,5))
sns.histplot(
    data=data,
    x="age",
    hue="who",
    kde=True,
    bins=25,
    palette="viridis",   
    alpha=0.7,           
    edgecolor="black")

plt.title("Age Distribution by Passenger Type", fontsize=14, fontweight="bold")
plt.xlabel("Age", fontsize=12)
plt.ylabel("Count", fontsize=12)
plt.show()

# %%
data = sns.load_dataset("tips")
print(data)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ## Scatter Plot
#
# * Visualized relationship between `total_bill` and `tip`, with categorical hue (`day`), size (`size`), and `markers`.
# * Experimented with `color` and `styling`.

# %%
sns.scatterplot(data =data ,x ="total_bill",y = "tip",hue = "day",size = "size",marker="o",color= 'viridis')
plt.title("Total Bill vs Tip by Day", fontsize=16, weight='bold')
plt.xlabel("Total Bill ($)", fontsize=12)
plt.ylabel("Tip ($)", fontsize=12)

plt.tight_layout()
plt.show()

# %%
data  = pd.read_excel("C:/Users/Shubham/Downloads/Excel course/datasets/ESD.xlsx")
print(data)
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0    Research & Development  Female      Black   55 2016-04-08         141604
# ...

# %%
sns.scatterplot(data =data , x = "Age",y = "Annual Salary",size = "Bonus %", hue= "Department")
plt.legend(bbox_to_anchor =(0.2,0,1.2,1)) #x,y,width,height
plt.show()

# %%
data = sns.load_dataset("tips")
print(data)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ## Heatmap (Groupby Aggregation)
#
# * Aggregated average `tip` by `day` and plotted with a heatmap.
# * Learned about handling pandas `FutureWarning` with `observed`.

# %%
gp = data.groupby("day", observed=True).agg({"tip":"mean"})
sns.heatmap(gp)
plt.show()

# %%
data = pd.read_excel("ESD.xlsx")
print(data)
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0    Research & Development  Female      Black   55 2016-04-08         141604
# ...

# %% [markdown]
# ## Heatmap of Annual Salary by Job
# - Aggregated mean `annual salary` by `job title`.
# - Visualized salary distribution using a heatmap (darker shades = higher salary).

# %%
gp = data.groupby("Job Title").agg({"Annual Salary":"mean"})
sns.heatmap(gp)
plt.show()

# %% [markdown]
# ## Employee Count per Department
# - Counted employees across `departments`.
# - Displayed results in a `bar` chart with clear labeling and formatting.

# %%
sns.set_theme(style="whitegrid")
plt.figure(figsize=(10,6))
sns.countplot(
    data=data, 
    x="Department",
    hue="Department",  
    palette="viridis",
    edgecolor="black")
plt.title("Employee Count per Department", fontsize=16, weight='bold')
plt.xlabel("Department", fontsize=12)
plt.ylabel("Count", fontsize=12)
#plt.xticks(rotation=45)       
plt.show()

# %%
data = pd.read_excel("ESD.xlsx")
df = pd.DataFrame(data)
print(df)
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0    Research & Development  Female      Black   55 2016-04-08         141604
# ...

# %% [markdown]
# ## Countplot by Ethnicity & Gender
# - Compared employee distribution across `ethnic` groups.
# - Split by `gender` using color-coded bars for better comparison.

# %%
sns.countplot(data=data,x = "Ethnicity",hue = "Gender" ,palette ="GnBu")
plt.show()

# %%
data = sns.load_dataset("tips")
print(data)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ## Violin Plot of Tips
# - Visualized the distribution of `tip` amounts.
# - Showed `spread`, `density`, and `median` in a single plot.

# %%
sns.violinplot(data =data ,x = "tip")
# Out:
# <Axes: xlabel='tip'>

# %%
data= pd.read_excel("ESD.xlsx")
df = pd.DataFrame(data)
print(df)
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0    Research & Development  Female      Black   55 2016-04-08         141604
# ...

# %% [markdown]
# ## Violin Plot of Annual Salary
# - Displayed salary distribution across `employees`.
# - Highlighted `median` and `variation` in `salary` using violin shape.

# %%
sns.violinplot(data =data ,x ="Annual Salary")
plt.show()

# %% [markdown]
# ## Pairplot
# - Compared multiple numerical features (`total_bill`, `tip`, `size`).
# - Colored by `day` to show group differences.
# - Combined scatterplots, KDE, and histograms for multivariate insights.

# %%
#pairplot
data = sns.load_dataset("tips")
sns.pairplot(data,hue ="day")
plt.show()

# %%
data = sns.load_dataset("iris")
print(data)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Pairplot of Iris Dataset
# - Compared `sepal` and `petal` measurements across `species`.
# - `Scatterplots` highlighted separability between species.
# - Diagonal `KDE` plots showed distribution per feature.

# %%
sns.pairplot(data,hue = "species")
plt.show()

# %% [markdown]
# ## Categorical Scatterplot (Tips Dataset)
# - Plotted `total bill` against `day`, split by `gender`.
# - Used `jitter` to reduce overlapping points.
# - Showed spending patterns across `weekdays` by `gender`.

# %%
#stripplot
data = sns.load_dataset("tips")
sns.stripplot(data=data,x = "day",y = "total_bill" ,hue = "sex",dodge = True,jitter =0.2)
plt.show()

# %% [markdown]
# ## Stripplot of Tips
# - Visualized raw distribution of `total bills` by `day`.
# - Useful for detecting `clustering` and `spread`.

# %%
data = sns.load_dataset("tips")
sns.scatterplot(data=data,x = "day",y = "total_bill")
plt.show()

# %% [markdown]
# ## Boxplot of Tips
# - Summarized distribution of `tip` by `day`.
# - Displayed `median`, `quartiles`, and `outliers`.

# %%
#boxplot
sns.boxplot(data=data,x = "day",y = "tip",orient = "vertical",fliersize=3)
plt.show()

# %% [markdown]
# ## Countplot of Total Bill by Day and Gender
# - Compared `total bill` distribution across `weekdays`.
# - Split by `gender` for better subgroup analysis.
# - `cat` plot stands for categorical plot

# %%
#catplot
sns.catplot(data=data,x = "day",hue="sex",kind = "count")
plt.show()

# %%
data = sns.load_dataset("exercise")
print(data)
# Out:
#     Unnamed: 0  id     diet  pulse    time     kind
# 0            0   1  low fat     85   1 min     rest
# 1            1   1  low fat     85  15 min     rest
# 2            2   1  low fat     88  30 min     rest
# 3            3   2  low fat     90   1 min     rest
# 4            4   2  low fat     92  15 min     rest
# ..         ...  ..      ...    ...     ...      ...
# 85          85  29   no fat    135  15 min  running
# 86          86  29   no fat    130  30 min  running
# 87          87  30   no fat     99   1 min  running
# 88          88  30   no fat    111  15 min  running
# 89          89  30   no fat    150  30 min  running
#
# [90 rows x 6 columns]

# %% [markdown]
# ## Barplot of Average Total Bill by Time
# - Displayed mean `total bill` for `lunch` vs `dinner`.
# - Showed confidence intervals for comparison.

# %%
#style and colotr in seaborn
sns.set_style(style = "ticks")
sns.barplot(data=data,x = "time",y="pulse")
plt.show()

# %% [markdown]
# ## Color Palette Demonstrations
# - Visualized different Seaborn color palettes.
# - `color_palette("Set1")` → strong contrasting colors.

# %%
sns.palplot(sns.color_palette())
plt.show()

# %% [markdown]
# `color_palette("Set2")` → softer, muted tones.

# %%
sns.palplot(sns.color_palette("viridis"))
plt.show()

# %% [markdown]
# `color_palette("Set3")` → pastel-like shades.

# %%
sns.palplot(sns.color_palette("spring"))
plt.show()

# %% [markdown]
# ## Categorical Scatterplot (Tips Dataset)
# - Plotted `total bill` vs `day`, grouped by `gender`.
# - Useful for spotting spending variation patterns.

# %%
#swarm plot
data = sns.load_dataset("tips")
sns.swarmplot(data,x = "day", y = "total_bill",hue = "sex",dodge =True)
plt.show()

# %% [markdown]
# ## Stacked Density Plot (KDE with Fill)
# - Visualized distribution of `total bill` across `weekdays`.
# - Used filled `KDE` to show proportions by `day`.
# - Highlighted contribution of each day to overall distribution.

# %%
#kde plot
data = sns.load_dataset("tips")
sns.kdeplot(data = data,x = "total_bill",hue = "day",multiple ="fill")
plt.show()

# %% [markdown]
# ## KDE Plot of Total Bill by Day
# - Compared `density` curves of `total bill` for each `day`.
# - Clear visualization of spending peaks and overlaps.
# - Easier to observe central tendency and spread per `day`.

# %%
data = sns.load_dataset("tips")
sns.kdeplot(data = data,x = "total_bill",hue ="day")
plt.show()
